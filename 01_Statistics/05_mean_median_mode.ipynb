# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/01_Statistics/05_mean_median_mode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
import numpy
speed=[99,87,98,65,77,87]

x=numpy.mean(speed)
print("Mean:",x)

y=numpy.median(speed)
print("Median:",y)

z=statistics.mode(speed)
print("Mode:",z)
# Out:
# Mean: 85.5
# Median: 87.0
# Mode: 87
