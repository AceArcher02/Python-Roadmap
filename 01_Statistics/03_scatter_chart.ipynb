# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/01_Statistics/03_scatter_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x=[6,5,2,3,5]
y=[3,9,6,10,1]

plt.scatter(x,y)
plt.show()
