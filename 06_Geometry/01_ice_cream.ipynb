# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/06_Geometry/01_ice_cream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ice Cream Cone Shape
print("""
           .-----.
         .'       '.
        /           \
       |             |
        \           /
         '.       .'
           '-----'
            \   /
             \ /
              V""")
# Out:
#            .-----.
#          .'       '.
#         /                  |             |
#         \           /
#          '.       .'
#            '-----'
#             \   /
#              \ /
#               V
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_2378/763104912.py:7: SyntaxWarning: invalid escape sequence '\ '
#   \           /
