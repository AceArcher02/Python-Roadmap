# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorithm/13_block_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#given a list of blocked ip address check if the current IP is in the list

blocked=["192.169.1.1","10.0.0.5"]
current_ip="10.0.0.5"

if current_ip in blocked:
    print("Threat Detected:IP blocked.")
else:
     print("Connection safe.")
# Out:
# Threat Detected:IP blocked.
