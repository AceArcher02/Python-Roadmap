# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorithm/11_username_length_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Accept username if it's 5-15 characters long

username=input("Enter username:")
if(5<=len(username)<=15):
   print("Valid Username")
else:
     print("Invalid length")
# Out:
# Enter username:Ace
# Invalid length
