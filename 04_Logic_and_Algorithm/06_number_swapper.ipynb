# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorithm/06_number_swapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=10

print(f"Before: a={a},b={b}")
print(f"Before: a={b},b={a}")
# Out:
# Before: a=5,b=10
# Before: a=10,b=5
