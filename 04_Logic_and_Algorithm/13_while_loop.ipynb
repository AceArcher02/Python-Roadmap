# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorithm/12_while_loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    code = input("Enter the password: ")

    if code == "Pancakes":
        print("System Unlocked.")
        break
    else:
        print("Wrong code. Try again.")
# Out:
# Enter the password: Cinnamon
# Wrong code. Try again.
# Enter the password: Cookie
# Wrong code. Try again.
# Enter the password: Pancakes
# System Unlocked.
