# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorithm/08_password_vault.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
password=input("Enter password:")
if(password=="Admin123"):
   print("ACCESS GRANTED")
else:
     print("ACCESS DENIED")
# Out:
# Enter password:Ace
# ACCESS DENIED

# %%
password=input("Enter password:")
if(password=='Admin123'):
   print("ACCESS GRANTED")
else:
     print("ACCESS DENIED")
