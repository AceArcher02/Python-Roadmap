# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorithm/Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string=input("Enter a string:")
if(string==string[::-1]):
   print("The string is a palindrome")
else:
     print("Not a palindrome")
# Out:
# Enter a string:kanak
# The string is a palindrome
