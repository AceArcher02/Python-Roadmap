# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorithm/display_triangle_pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rows = 5
for i in range(1, rows ,+ 1):
    for j in range(1, i ,+ 1):
        print(j, end="")
    print(i)
# Out:
# 1
# 12
# 123
# 1234
