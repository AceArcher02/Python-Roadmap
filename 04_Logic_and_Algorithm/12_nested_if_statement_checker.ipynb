# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/04_Logic_and_Algorithm/12_nested_if_statement_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check if the user is of age and if they have permit

age=int(input("Enter age:"))
has_permit=input("Do you have permit:true or false").lower() == 'true'
if(age>=18):
   if has_permit:
      print("Access Granted")
   else:
        print("Identity verification required")
else:
     print("Access Denied")
# Out:
# Enter age:19
# Do you have permit:true or falseTrue
# Access Granted
