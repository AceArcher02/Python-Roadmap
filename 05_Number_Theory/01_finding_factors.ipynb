# %% [markdown]
# <a href="https://colab.research.google.com/github/AceArcher02/Python-Roadmap/blob/main/05_Number_Theory/finding_factors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input("Enter a number: "))
for i in range(1, x + 1,+1):
    if (x % i == 0):
        print(i)
# Out:
# Enter a number: 22574
# 1
# 2
# 11287
# 22574
